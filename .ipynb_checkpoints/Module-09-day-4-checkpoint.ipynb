# %% [markdown]
# ---
#
#
# # **Data Science and Machine Learning for Environmental Engineering**
#
#
# ---

# %% [markdown]
# ---
# # **Module 9**
# ---

# %% [markdown]
# # Before we start
#
# ![Data Science Workflow](https://www.tutorialspoint.com/google_colab/images/saving_google_drive.jpg)

# %% [markdown]
# ---
# # Build metrics for ML comparison
# ---
